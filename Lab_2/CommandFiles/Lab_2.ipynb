# %%
import pandas as pd

# Wczytanie pliku i wyświetlenie oryginalnej tablicy
direction = "C:/Users/WINKLER/Desktop/AiBD/analiza-i-bazy-danych/Analiza_i_bazy_danych/Lab_2/OriginalData/billboard.csv"

billboards = pd.read_csv(direction)
billboards
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
# ...

# %%
#  Wczytanie danych i usunięcie pustych kolumn

billboards = pd.read_csv(direction)
billboards = billboards.dropna(axis = 1, how = 'any')
billboards
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
#     genre date.entered date.peaked  x1st.week
# ...

# %%
# Wczytanie pliku oryginalnego

billboards = pd.read_csv(direction)

# Usunięcie pustych kolumn
billboards = billboards.dropna(axis = 1, how = 'any')

# Uporządkowane dane - możliwość odczytania jaką pozycję na liście 
# zajmowali konkretni artyści (2 kolumna) ze swoimi utworami (3 kolumna) w pierwszym tygodniu 
# zestawienia (4 kolumna)
billboard_new = billboards[['artist.inverted', 'track', 'x1st.week']].sort_values('x1st.week')
billboard_new
# Out:
#                   artist.inverted                       track  x1st.week
# 1                         Santana                Maria, Maria         15
# 80                         Hanson            This Time Around         22
# 45                           Pink                  There U Go         25
# 114                 Carey, Mariah                     Crybaby         28
# 35   Elliott, Missy "Misdemeanor"                    Hot Boyz         36
# ..                            ...                         ...        ...
# 303                       Lil' Mo                       Ta Da        100
# 300                   Herndon, Ty                    No Mercy        100
# 307                Larrieux, Amel                      Get Up        100
# 248                         Drama           Left, Right, Left        100
# 47                          Nelly  (Hot S**t) Country Grammar        100
#
# [317 rows x 3 columns]

# %%
# Stworzenie nowego pliku z czytelnym rankingiem w pierwszym tygodniu

billboard_new.to_csv(path_or_buf="C:/Users/WINKLER/Desktop/AiBD/analiza-i-bazy-danych/Analiza_i_bazy_danych/Lab_2/AnalysisData/billboard_new.csv", index=False)
print(billboard_new)
# Out:
#                   artist.inverted                       track  x1st.week
# 1                         Santana                Maria, Maria         15
# 80                         Hanson            This Time Around         22
# 45                           Pink                  There U Go         25
# 114                 Carey, Mariah                     Crybaby         28
# 35   Elliott, Missy "Misdemeanor"                    Hot Boyz         36
# ..                            ...                         ...        ...
# 303                       Lil' Mo                       Ta Da        100
# 300                   Herndon, Ty                    No Mercy        100
# 307                Larrieux, Amel                      Get Up        100
# 248                         Drama           Left, Right, Left        100
# 47                          Nelly  (Hot S**t) Country Grammar        100
#
# [317 rows x 3 columns]
